# %%
# import packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
#read datafiles (change to raw.github)
df_corona = pd.read_csv("/Users/kariannekies/Downloads/owid-covid-data-2.csv")
df_F = pd.read_csv("/Users/kariannekies/Documents/COVID-Temp/Raw Data/Daily_Temp_France.csv")

# %%
df_F["STATION"].unique().tolist()
# Out:
#          STATION  LATITUDE  LONGITUDE  ELEVATION        DATE  TAVG  TMAX  TMIN
# 691  FR000007150   48.8231     2.3367       75.0  2020-11-28   7.2  11.8   4.9
# 692  FR000007150   48.8231     2.3367       75.0  2020-11-29   3.8   7.9   NaN
# 693  FR000007150   48.8231     2.3367       75.0  2020-11-30   3.6   NaN   1.0
# 694  FR000007150   48.8231     2.3367       75.0  2020-12-01   7.8   9.2   4.3
# 695  FR000007150   48.8231     2.3367       75.0  2020-12-02   7.6   8.6   NaN
# 696  FR000007150   48.8231     2.3367       75.0  2020-12-03   6.6   NaN   5.8
# 697  FR000007150   48.8231     2.3367       75.0  2020-12-04   5.7   8.1   NaN
# 698  FR000007150   48.8231     2.3367       75.0  2020-12-05   4.9   6.5   3.0
# 699  FR000007150   48.8231     2.3367       75.0  2020-12-06   5.0   7.0   NaN
# 700  FR000007150   48.8231     2.3367       75.0  2020-12-07   3.8   5.7   2.1
# 701  FR000007150   48.8231     2.3367       75.0  2020-12-08   3.7   5.7   NaN
# ...

# %%
#Prepare data
df_F["STATION"] = df_F["STATION"].replace(["FR000007150","FRM00007149"], "France")
df_F=df_F[["STATION","DATE","TAVG"]]

df_FCor= df_corona.loc[df_corona["location"]=="France"]

# %%
#merge datasets
dataF = df_FCor.merge(df_F, left_on="date", right_on="DATE")

# %%
dataF=dataF[["location", "date","TAVG","new_cases", "total_cases", "total_deaths","new_deaths","new_deaths_smoothed"]]
